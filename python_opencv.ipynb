# %%
import cv2

# %%
img=cv2.imread("/content/obama cry.webp")

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) #bgr

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB)) #RGB

# %%
# !pip install deepface

# %%
from deepface import DeepFace
pred=DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.36it/s]

# %%
type(pred)
# Out:
# list

# %%
prediction=pred[0]
prediction["dominant_emotion"]
# Out:
# 'sad'

# %%
#rectangle across the face

# %%
from cv2 import CascadeClassifier

# %%
=faceCascadecv2.CascadeClassifier(cv2.data.haarcascades+"haarcascade_frontalface_default.xml")
(faceCascade)
# Out:
#   File "<ipython-input-38-401b42e8a2a4>", line 1
#     =faceCascadecv2.CascadeClassifier(cv2.data.haarcascades+"haarcascade_frontalface_default.xml")
#     ^
# SyntaxError: invalid syntax

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray

# %%
faces = faceCascade.detectMultiScale(gray, 1.1, 4)

# %%
for(x,y,w,h) in faces:
  cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB)) #RGB

# %%
font=cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,prediction['dominant_emotion'],(50,50),font,3,(0,255,0),2,cv2.LINE_4)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB)) #RGB

# %%
#real time video

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2
from deepface import DeepFace
# create an instance of VideoCapture to access the default webcam

faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades+"haarcascade_frontalface_default.xml")
cap=cv2.VideoCapture(1)
if not cap.isOpened():
  cap=cv2.VideoCapture(0)
# loop to continuously capture frames from the webcam
while True:
  ret,frame=cap.read()
  result=DeepFace.analyze(frame, actions = ['emotion'])

  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  faces = faceCascade.detectMultiScale(gray, 1.1, 4)
  for(x,y,w,h) in faces:
   cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

  font=cv2.FONT_HERSHEY_SIMPLEX
  cv2.putText(img,prediction['dominant_emotion'],(50,50),font,3,(0,255,0),2,cv2.LINE_4)

  if cv2.waitKey(2)&0xFF==ord('q'):
    break


# release the VideoCapture and destroy all windows
cap.release()
cv2.destroyAllWindows()

# %%
import cv2

# Load the pre-trained face detection classifier
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades+"haarcascade_frontalface_default.xml")

# Load the video file
cap = cv2.VideoCapture('/content/moooha.gif')

while True:
    # Read each frame from the video
    ret, frame = cap.read()

    if ret:
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faces = faceCascade.detectMultiScale(gray, 1.1, 4)
        for(x,y,w,h) in faces:
          cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

        font=cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(img,prediction['dominant_emotion'],(50,50),font,3,(0,255,0),2,cv2.LINE_4)
    if cv2.waitKey(2)&0xFF==ord('q'):
      break

# Release the capture and destroy the window
cap.release()
cv2.destroyAllWindows()
